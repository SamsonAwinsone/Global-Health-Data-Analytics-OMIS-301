# %%
#part 2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('classwork.xlsx')

# %% [markdown]
# #EDA

# %%
df.head()
# Out:
#      Country  Year         Disease Name Disease Category  Prevalence Rate (%)  \
# 0      Italy  2013              Malaria      Respiratory                 0.95
# 1     France  2002                Ebola        Parasitic                12.46
# 2     Turkey  2015             COVID-19          Genetic                 0.91
# 3  Indonesia  2011  Parkinson's Disease       Autoimmune                 4.68
# 4      Italy  2013         Tuberculosis          Genetic                 0.83
#
#    Incidence Rate (%)  Mortality Rate (%) Age Group Gender  \
# 0                1.55                8.42      0-18   Male
# 1                8.63                8.75       61+   Male
# 2                2.35                6.22     36-60   Male
# 3                6.29                3.99      0-18  Other
# 4               13.59                7.01       61+   Male
#
#    Population Affected  ...  Hospital Beds per 1000  Treatment Type  \
# 0               471007  ...                    7.58      Medication
# ...

# %%
df.tail()
# Out:
#            Country  Year         Disease Name Disease Category  \
# 1495  Saudi Arabia  2014               Asthma     Neurological
# 1496     Argentina  2018                Polio      Respiratory
# 1497     Indonesia  2000  Alzheimer's Disease     Neurological
# 1498        Brazil  2008               Asthma        Metabolic
# 1499       Germany  2000              Measles      Respiratory
#
#       Prevalence Rate (%)  Incidence Rate (%)  Mortality Rate (%) Age Group  \
# 1495                12.51                6.54                8.14      0-18
# 1496                18.46                3.33                7.59     36-60
# 1497                 4.36               12.74                1.76       61+
# 1498                 2.52                4.79                7.74     19-35
# 1499                14.03               14.88                1.21     19-35
#
#       Gender  Population Affected  ...  Hospital Beds per 1000  \
# ...

# %%
numerical_stat=df.describe()
print(numerical_stat)
# Out:
#               Year  Prevalence Rate (%)  Incidence Rate (%)  \
# count  1500.000000          1500.000000         1500.000000
# mean   2011.789333            10.272320            7.519700
# std       7.210984             5.726204            4.275134
# min    2000.000000             0.110000            0.110000
# 25%    2006.000000             5.447500            3.877500
# 50%    2011.500000            10.550000            7.475000
# 75%    2018.000000            15.130000           11.182500
# max    2024.000000            20.000000           15.000000
#
#        Mortality Rate (%)  Population Affected  Healthcare Access (%)  \
# count         1500.000000          1500.000000             1500.00000
# mean             5.032247        500031.944667               74.97818
# std              2.838037        288853.513742               14.72358
# min              0.100000          3062.000000               50.00000
# 25%              2.550000        245990.000000               61.99750
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             1500 non-null   object
#  1   Year                                1500 non-null   int64
#  2   Disease Name                        1500 non-null   object
#  3   Disease Category                    1500 non-null   object
#  4   Prevalence Rate (%)                 1500 non-null   float64
#  5   Incidence Rate (%)                  1500 non-null   float64
#  6   Mortality Rate (%)                  1500 non-null   float64
#  7   Age Group                           1500 non-null   object
#  8   Gender                              1500 non-null   object
#  9   Population Affected                 1500 non-null   int64
#  10  Healthcare Access (%)               1500 non-null   float64
# ...

# %%
categorical=df.select_dtypes(include = 'object').columns

# %%
print (categorical)
# Out:
# Index(['Country', 'Disease Name', 'Disease Category', 'Age Group', 'Gender',
#        'Treatment Type', 'Availability of Vaccines/Treatment'],
#       dtype='object')

# %%
df=df[['Country', 'Disease Name', 'Disease Category', 'Age Group', 'Gender',
       'Treatment Type', 'Availability of Vaccines/Treatment']].copy()
df.head()
# Out:
#      Country         Disease Name Disease Category Age Group Gender  \
# 0      Italy              Malaria      Respiratory      0-18   Male
# 1     France                Ebola        Parasitic       61+   Male
# 2     Turkey             COVID-19          Genetic     36-60   Male
# 3  Indonesia  Parkinson's Disease       Autoimmune      0-18  Other
# 4      Italy         Tuberculosis          Genetic       61+   Male
#
#   Treatment Type Availability of Vaccines/Treatment
# 0     Medication                                 No
# 1        Surgery                                Yes
# 2    Vaccination                                Yes
# 3        Surgery                                Yes
# 4     Medication                                Yes

# %%
sns.displot(x='Prevalence Rate (%)', data=df)

# %%
sns.histplot(x='Prevalence Rate (%)', data=df)
# Out:
# <Axes: xlabel='Prevalence Rate (%)', ylabel='Count'>

# %%
sns.histplot(x='Mortality Rate (%)' ,data=df,color='orange')
# Out:
# <Axes: xlabel='Mortality Rate (%)', ylabel='Count'>

# %%
sns.barplot(x='Healthcare Access (%)',y='Country',data=df,color='pink')
# Out:
# <Axes: xlabel='Healthcare Access (%)', ylabel='Country'>

# %%
#three diseases with highest prevalence rate
sns.barplot(y='Disease Name',x='Prevalence Rate (%)',data=df,color='black')
# Out:
# <Axes: xlabel='Prevalence Rate (%)', ylabel='Disease Name'>

# %% [markdown]
# #  INSIGHTS ON DISEASES PREVALENCE AND HEALTH CARE INVESTMENT

# %%
top_diseases=df[['Disease Name','Prevalence Rate (%)']].sort_values(by='Prevalence Rate (%)',ascending=False).head(3)
print(top_diseases)
# Out:
#      Disease Name  Prevalence Rate (%)
# 1111     Diabetes                20.00
# 323          Zika                20.00
# 1379      Measles                19.98

# %%
#2b)countries with more investment
invest=df[['Country','Doctors per 1000']].sort_values(by='Doctors per 1000',ascending =True).head(3)
print(invest)
# Out:
#      Country  Doctors per 1000
# 1156  Turkey              0.50
# 1188   India              0.50
# 689   Turkey              0.51

# %% [markdown]
# # CORRELATION ANALYSIS

# %%
3a) #correlatin analysis
correlate=df[['Education Index','Per Capita Income (USD)','Prevalence Rate (%)']].corr()
print(correlate)
# Out:
#                          Education Index  Per Capita Income (USD)  \
# Education Index                 1.000000                 0.023740
# Per Capita Income (USD)         0.023740                 1.000000
# Prevalence Rate (%)             0.058633                 0.010274
#
#                          Prevalence Rate (%)
# Education Index                     0.058633
# Per Capita Income (USD)             0.010274
# Prevalence Rate (%)                 1.000000

# %%
3b)sns.scatterplot(x='Education Index',y='Per Capita Income (USD)',data=df)
# Out:
# <Axes: xlabel='Education Index', ylabel='Per Capita Income (USD)'>

# %%
sns.scatterplot(x='Education Index',y='Prevalence Rate (%)',data=df,color='red')
# Out:
# <Axes: xlabel='Education Index', ylabel='Prevalence Rate (%)'>

# %%
sns.scatterplot(x='Per Capita Income (USD)',y='Prevalence Rate (%)', data=df,color='brown')
plt.title('Per Capita Income vs.Prevalence Rate (%)')
# Out:
# Text(0.5, 1.0, 'Per Capita Income vs.Prevalence Rate (%)')

# %% [markdown]
# # 4 targeted inventions and public health  campaigns

# %%
#4a countries with highest disease burden 
highest_disease=df[['Country','DALYs']].sort_values(by='DALYs',ascending = False).head()
print(highest_disease )
# Out:
#         Country  DALYs
# 394      Russia   4999
# 23        Japan   4994
# 201       Italy   4989
# 1144  Indonesia   4988
# 1305     Canada   4986

# %%
#4b1 individuals should be aware of diseases such as diabetes,zika and Measles
    #2counties with higher disease  burden such as Russia, Japan  and Italy
       #Increase awareness about maternal and child health'

# %% [markdown]
# # 4C Visualization to support dsease prevalence

# %%
#4C Visualization to support dsease prevalence 
sns.barlot(y='Disease Name',x='Prevalence Rate (%)',data=df,color='grey')
# Out:
# <Axes: xlabel='Prevalence Rate (%)', ylabel='Disease Name'>

# %%
sns.catplot(x='Country',y='DALYs',data=highest_disease)

# %%
# ID'S 
11207632
11219536
11325879
